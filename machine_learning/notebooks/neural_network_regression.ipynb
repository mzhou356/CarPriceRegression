# %% [markdown]
# ### Import libraries

# %%
import sys
import os
import gc
import warnings
from functools import partial
warnings.filterwarnings("ignore")

# %%
home = os.path.expanduser("~")
sys.path.append(f"{home}/Documents/projects/CarPriceRegression/machine_learning/scripts/")

# %%
from data_set_up import DataSetUp
from nn_car_price import pd, np, NnCarPrice, tfk
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
NnCarPrice.set_gpu_limit(6)

# %% [markdown]
# ### Import data for regular NN without categorical embedding and split into train,dev, and test

# %%
data = pd.read_csv(f"{home}/Documents/projects/CarPriceRegression/processed_data/car_onehot_data.csv")
features,y = data.drop("price",axis=1), data.price

# %%
data_setup = DataSetUp(features,y)

# %%
X_train,X_dev,X_test,y_train,y_dev,y_test = data_setup.data_split(2020,0.1,dev_set=True,dev_seed=1988,dev_size=0.11)

# %% [markdown]
# ### Garbage collect

# %%
gc.collect()
# %reset -f out
# Out:
# Flushing output cache (0 entries)

# %% [markdown]
# ### Set up base parameter for a base regression model

# %%
BATCH_SIZE = 256 
input_size = data.drop("price",axis=1).shape[1]
MAX_EPOCH = 500
lr = 1e-3
l2 = 0 
SIZES = [512,512]
METRICS = ["MAPE","MAE"]

# %% [markdown]
# ### Set up a base regression model

# %%
base_model = NnCarPrice.make_model(SIZES,input_size,METRICS,l2,lr)

# %%
base_model.summary()
# Out:
# Model: "NN_regressor"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               112640
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 375,809
# Trainable params: 375,809
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Define early stop

# %%
EARLYSTOP = tfk.callbacks.EarlyStopping(monitor="val_loss",mode="min",
                                        patience=10,verbose=1,restore_best_weights=True)

# %% [markdown]
# ### Set up a base regression model

# %%
CarPrice_NN_base = NnCarPrice(base_model,BATCH_SIZE,MAX_EPOCH,[EARLYSTOP])

# %% [markdown]
# ### Make tensorflow dataset
#
# * notice: this dataset has pretty similar scale so no reason to normalize to help with gradient descent

# %%
train_dataset = DataSetUp.make_tensor_dataset(X_train,y_train,BATCH_SIZE)
dev_dataset = DataSetUp.make_tensor_dataset(X_dev,y_dev,BATCH_SIZE)

# %%
CarPrice_NN_base.regression_metrics(X_train.values,y_train,"train",True,train_dataset,dev_dataset,verbose=0)
# Out:
# Restoring model weights from the end of the best epoch.
# Epoch 00226: early stopping
#        r2_score         rmse  price_diff_abs_max
# train  0.942542  2360.517426         1125.499253

# %%
CarPrice_NN_base.regression_metrics(X_test.values,y_test,"test",retrain=False)
# Out:
#       r2_score         rmse  price_diff_abs_max
# test  0.936901  2423.056854         1247.708383

# %%
CarPrice_NN_base.save_model("base_nn_regression_mdl.h5")

# %% [markdown]
# ### Check price vs predicted value

# %%
CarPrice_NN_base.plot_pred_price(features,y,retrain=False)

# %%
price_table = CarPrice_NN_base.price_diff(features,y)

# %%
price_table.head(25)
# Out:
#        binned_year  mil_cat  binned_mpg  engine_binned  model_ 1 Series  \
# 39978            1        5           1              0                0
# 20061            1        0           1              0                0
# 11984            1        0           3              0                0
# 71819            1        0           2              0                0
# 40171            1        4           2              0                0
# 44539            1        4           3              0                0
# 69135            1        4           2              0                0
# 47201            1        5           2              0                0
# 39711            1        2           1              1                0
# 44553            1        4           2              0                0
# 72349            1        4           2              0                0
# 71571            1        0           1              0                0
# 71617            1        4           2              0                0
# 40172            1        2           1              2                0
# 78800            2        2           3              0                0
# 72016            1        5           2              0                0
# 289              1        4           1              0                0
# 43781            1        2           2              0                0
# 6309             1        5           4              0                0
# 44573            1        4           2              0                0
# 39540            1        5           1              1                0
# 44645            1        3           2              0                0
# 85021            1        5           1              1                0
# 40170            1        5           3              0                0
# 44745            1        5           3              0                0
#
#        model_ 2 Series  model_ 3 Series  model_ 4 Series  model_ 5 Series  \
# 39978                0                0                0                0
# 20061                0                0                0                0
# 11984                0                0                0                0
# 71819                0                0                0                0
# 40171                0                0                0                0
# 44539                0                0                0                0
# 69135                0                0                0                0
# 47201                0                0                0                0
# 39711                0                0                0                0
# 44553                0                0                0                0
# 72349                0                0                0                0
# 71571                0                0                0                0
# 71617                0                0                0                0
# 40172                0                0                0                0
# 78800                0                0                0                0
# 72016                0                0                0                0
# 289                  0                0                0                0
# 43781                0                0                0                0
# 6309                 0                0                0                0
# 44573                0                0                0                0
# 39540                0                0                0                0
# 44645                0                0                0                0
# 85021                0                0                0                1
# 40170                0                0                0                0
# 44745                0                0                0                0
#
#        model_ 6 Series  ...  brand_bmw  brand_ford  brand_hyundi  brand_merc  \
# 39978                0  ...          0           0             0           1
# 20061                0  ...          0           0             0           0
# 11984                0  ...          0           0             0           0
# 71819                0  ...          0           1             0           0
# 40171                0  ...          0           0             0           1
# 44539                0  ...          0           0             0           0
# 69135                0  ...          0           1             0           0
# 47201                0  ...          0           0             0           0
# 39711                0  ...          0           0             0           1
# 44553                0  ...          0           0             0           0
# 72349                0  ...          0           1             0           0
# 71571                0  ...          0           1             0           0
# 71617                0  ...          0           1             0           0
# 40172                0  ...          0           0             0           1
# 78800                0  ...          1           0             0           0
# 72016                0  ...          0           1             0           0
# 289                  0  ...          0           0             0           0
# 43781                0  ...          0           0             0           0
# 6309                 0  ...          0           0             0           0
# 44573                0  ...          0           0             0           0
# 39540                0  ...          0           0             0           1
# 44645                0  ...          0           0             0           0
# 85021                0  ...          1           0             0           0
# 40170                0  ...          0           0             0           1
# 44745                0  ...          0           0             0           0
#
#        brand_skoda  brand_toyota  brand_vauxhall  brand_vw  price_diff_pct  \
# 39978            0             0               0         0     1530.467398
# 20061            0             0               0         1      979.611026
# 11984            0             0               0         1      933.360548
# 71819            0             0               0         0      769.479227
# 40171            0             0               0         0      576.486599
# 44539            0             0               1         0      501.936898
# 69135            0             0               0         0      487.012261
# 47201            0             0               1         0      443.557780
# 39711            0             0               0         0      436.183045
# 44553            0             0               1         0      328.606040
# 72349            0             0               0         0      305.980678
# 71571            0             0               0         0      304.717727
# 71617            0             0               0         0      304.604197
# 40172            0             0               0         0      289.103629
# 78800            0             0               0         0      288.738478
# 72016            0             0               0         0      281.040631
# 289              0             1               0         0      277.231076
# 43781            0             0               1         0      268.374791
# 6309             0             1               0         0      267.340149
# 44573            0             0               1         0      261.253662
# 39540            0             0               0         0      260.001958
# 44645            0             0               1         0      253.906894
# 85021            0             0               0         0      253.703713
# 40170            0             0               0         0      247.649378
# 44745            0             0               1         0      247.278412
#
#        price_diff_abs
# 39978     1530.467398
# 20061      979.611026
# 11984      933.360548
# 71819      769.479227
# 40171      576.486599
# 44539      501.936898
# 69135      487.012261
# 47201      443.557780
# 39711      436.183045
# 44553      328.606040
# 72349      305.980678
# 71571      304.717727
# 71617      304.604197
# 40172      289.103629
# 78800      288.738478
# 72016      281.040631
# 289        277.231076
# 43781      268.374791
# 6309       267.340149
# 44573      261.253662
# 39540      260.001958
# 44645      253.906894
# 85021      253.703713
# 40170      247.649378
# 44745      247.278412
#
# [25 rows x 221 columns]

# %%
price_table.tail(25)
# Out:
#        binned_year  mil_cat  binned_mpg  engine_binned  model_ 1 Series  \
# 58720            3        2           4              0                0
# 59081            3        2           4              0                0
# 59068            3        2           4              0                0
# 58184            3        1           4              0                0
# 75818            3        3           3              0                0
# 74712            3        3           3              0                0
# 22129            4        0           4              0                0
# 1652             3        1           2              0                0
# 83875            4        1           1              1                0
# 80918            4        1           1              1                0
# 37486            3        3           4              1                0
# 94430            3        2           3              0                0
# 79217            2        2           4              0                0
# 87246            3        2           4              0                0
# 35983            4        0           1              1                0
# 82357            3        3           3              0                0
# 76735            3        1           3              0                0
# 85790            3        4           4              0                0
# 71799            3        1           3              0                0
# 80999            4        1           1              1                0
# 54776            4        2           2              0                0
# 98542            3        3           4              0                0
# 73021            3        2           3              0                0
# 73111            3        2           3              0                0
# 96262            4        0           1              1                0
#
#        model_ 2 Series  model_ 3 Series  model_ 4 Series  model_ 5 Series  \
# 58720                0                0                0                0
# 59081                0                0                0                0
# 59068                0                0                0                0
# 58184                0                0                0                0
# 75818                0                0                0                0
# 74712                0                0                0                0
# 22129                0                0                0                0
# 1652                 0                0                0                0
# 83875                0                0                0                0
# 80918                0                0                0                0
# 37486                0                0                0                0
# 94430                0                0                0                0
# 79217                0                0                0                1
# 87246                0                1                0                0
# 35983                0                0                0                0
# 82357                0                0                0                0
# 76735                0                0                0                0
# 85790                0                1                0                0
# 71799                0                0                0                0
# 80999                0                1                0                0
# 54776                0                0                0                0
# 98542                0                0                0                0
# 73021                0                0                0                0
# 73111                0                0                0                0
# 96262                0                0                0                0
#
#        model_ 6 Series  ...  brand_bmw  brand_ford  brand_hyundi  brand_merc  \
# 58720                0  ...          0           1             0           0
# 59081                0  ...          0           1             0           0
# 59068                0  ...          0           1             0           0
# 58184                0  ...          0           1             0           0
# 75818                0  ...          0           0             1           0
# 74712                0  ...          0           0             1           0
# 22129                0  ...          0           0             0           0
# 1652                 0  ...          0           0             0           0
# 83875                0  ...          1           0             0           0
# 80918                0  ...          1           0             0           0
# 37486                0  ...          0           0             0           1
# 94430                0  ...          0           0             0           0
# 79217                0  ...          1           0             0           0
# 87246                0  ...          1           0             0           0
# 35983                0  ...          0           0             0           1
# 82357                0  ...          1           0             0           0
# 76735                0  ...          0           0             1           0
# 85790                0  ...          1           0             0           0
# 71799                0  ...          0           1             0           0
# 80999                0  ...          1           0             0           0
# 54776                0  ...          0           0             0           0
# 98542                0  ...          0           0             0           0
# 73021                0  ...          0           0             1           0
# 73111                0  ...          0           0             1           0
# 96262                0  ...          0           0             0           0
#
#        brand_skoda  brand_toyota  brand_vauxhall  brand_vw  price_diff_pct  \
# 58720            0             0               0         0       -0.002589
# 59081            0             0               0         0       -0.002589
# 59068            0             0               0         0       -0.002589
# 58184            0             0               0         0       -0.002503
# 75818            0             0               0         0        0.002476
# 74712            0             0               0         0        0.002476
# 22129            1             0               0         0        0.002386
# 1652             0             1               0         0        0.002326
# 83875            0             0               0         0       -0.002102
# 80918            0             0               0         0       -0.001921
# 37486            0             0               0         0       -0.001584
# 94430            0             0               0         0        0.001430
# 79217            0             0               0         0        0.001126
# 87246            0             0               0         0       -0.001121
# 35983            0             0               0         0       -0.001084
# 82357            0             0               0         0        0.001026
# 76735            0             0               0         0        0.000966
# 85790            0             0               0         0        0.000871
# 71799            0             0               0         0       -0.000843
# 80999            0             0               0         0       -0.000782
# 54776            0             0               1         0        0.000514
# 98542            0             0               0         0        0.000352
# 73021            0             0               0         0        0.000172
# 73111            0             0               0         0        0.000172
# 96262            0             0               0         0        0.000158
#
#        price_diff_abs
# 58720        0.002589
# 59081        0.002589
# 59068        0.002589
# 58184        0.002503
# 75818        0.002476
# 74712        0.002476
# 22129        0.002386
# 1652         0.002326
# 83875        0.002102
# 80918        0.001921
# 37486        0.001584
# 94430        0.001430
# 79217        0.001126
# 87246        0.001121
# 35983        0.001084
# 82357        0.001026
# 76735        0.000966
# 85790        0.000871
# 71799        0.000843
# 80999        0.000782
# 54776        0.000514
# 98542        0.000352
# 73021        0.000172
# 73111        0.000172
# 96262        0.000158
#
# [25 rows x 221 columns]

# %%
feature_table = CarPrice_NN_base.linear_feature_importance(features,plot=True)

# %% [markdown]
# ### Pretty decent results and the error appear to be normal distribution

# %% [markdown]
# ## Try a bigger model

# %%
bigger_model = NnCarPrice.make_model([2056,2014,512,512],input_size,METRICS,1e-4,lr)

# %%
bigger_model.summary()
# Out:
# Model: "NN_regressor"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 2056)              452320
# _________________________________________________________________
# dense_4 (Dense)              (None, 2014)              4142798
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               1031680
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 5,889,967
# Trainable params: 5,889,967
# Non-trainable params: 0
# _________________________________________________________________

# %%
CarPrice_NN_bigger = NnCarPrice(bigger_model,BATCH_SIZE,MAX_EPOCH,[EARLYSTOP])

# %%
CarPrice_NN_bigger.regression_metrics(X_train.values,y_train,"train",True,train_dataset,dev_dataset,verbose=0)
# Out:
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
#        r2_score         rmse  price_diff_abs_max
# train  0.942564  2360.073991          822.771799

# %%
CarPrice_NN_bigger.regression_metrics(X_test.values,y_test,"test",False)
# Out:
#       r2_score         rmse  price_diff_abs_max
# test  0.937605  2409.496968          323.653358

# %%
CarPrice_NN_bigger.save_model("bigger_model_nn.h5")

# %%
CarPrice_NN_bigger.plot_pred_price(features,y,retrain=False)

# %% [markdown]
# ### Pretty decent result and not over training the train data either

# %%
bigger_model_2 = NnCarPrice.make_model([2056,2014,512,512],input_size,METRICS,1e-4,5e-5)

# %%
bigger_model_2.summary()
# Out:
# Model: "NN_regressor"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 2056)              452320
# _________________________________________________________________
# dense_9 (Dense)              (None, 2014)              4142798
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               1031680
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 5,889,967
# Trainable params: 5,889,967
# Non-trainable params: 0
# _________________________________________________________________

# %%
CarPrice_NN_bigger_2 = NnCarPrice(bigger_model_2,BATCH_SIZE,MAX_EPOCH,[EARLYSTOP])

# %%
CarPrice_NN_bigger_2.regression_metrics(X_train.values,y_train,"train",True,train_dataset,dev_dataset,0)
# Out:
# Restoring model weights from the end of the best epoch.
# Epoch 00117: early stopping
#        r2_score         rmse  price_diff_abs_max
# train  0.944811  2313.454362          851.316367

# %%
CarPrice_NN_bigger_2.regression_metrics(X_test.values,y_test,"test",False)
# Out:
#       r2_score         rmse  price_diff_abs_max
# test  0.939024  2381.948375           659.20598

# %%
CarPrice_NN_bigger_2.save_model("bigger_model_2.h5")

# %%
CarPrice_NN_bigger_2.reset_trained_model(bigger_model_2)

# %%
CarPrice_NN_bigger_2.plot_pred_price(features,y,False)

# %% [markdown]
# ### Since we have limited data, having bigger NN didn't seem to help with the improvement
#
# ------
#
# ### Looking at special cases of why the model has hard time predicting certain car price

# %%
price_table_final = CarPrice_NN_bigger_2.price_diff(features,y)

# %%
price_table_final.head(20)
# Out:
#        binned_year  mil_cat  binned_mpg  engine_binned  model_ 1 Series  \
# 11984            1        0           3              0                0
# 71819            1        0           2              0                0
# 39711            1        2           1              1                0
# 39978            1        5           1              0                0
# 69135            1        4           2              0                0
# 39540            1        5           1              1                0
# 44539            1        4           3              0                0
# 77582            1        4           1              1                0
# 71617            1        4           2              0                0
# 40171            1        4           2              0                0
# 47201            1        5           2              0                0
# 72349            1        4           2              0                0
# 40172            1        2           1              2                0
# 78800            2        2           3              0                0
# 44553            1        4           2              0                0
# 20061            1        0           1              0                0
# 40019            1        3           1              0                0
# 83274            2        3           2              0                0
# 43781            1        2           2              0                0
# 289              1        4           1              0                0
#
#        model_ 2 Series  model_ 3 Series  model_ 4 Series  model_ 5 Series  \
# 11984                0                0                0                0
# 71819                0                0                0                0
# 39711                0                0                0                0
# 39978                0                0                0                0
# 69135                0                0                0                0
# 39540                0                0                0                0
# 44539                0                0                0                0
# 77582                0                0                0                0
# 71617                0                0                0                0
# 40171                0                0                0                0
# 47201                0                0                0                0
# 72349                0                0                0                0
# 40172                0                0                0                0
# 78800                0                0                0                0
# 44553                0                0                0                0
# 20061                0                0                0                0
# 40019                0                0                0                0
# 83274                0                0                0                0
# 43781                0                0                0                0
# 289                  0                0                0                0
#
#        model_ 6 Series  ...  brand_bmw  brand_ford  brand_hyundi  brand_merc  \
# 11984                0  ...          0           0             0           0
# 71819                0  ...          0           1             0           0
# 39711                0  ...          0           0             0           1
# 39978                0  ...          0           0             0           1
# 69135                0  ...          0           1             0           0
# 39540                0  ...          0           0             0           1
# 44539                0  ...          0           0             0           0
# 77582                0  ...          0           0             1           0
# 71617                0  ...          0           1             0           0
# 40171                0  ...          0           0             0           1
# 47201                0  ...          0           0             0           0
# 72349                0  ...          0           1             0           0
# 40172                0  ...          0           0             0           1
# 78800                0  ...          1           0             0           0
# 44553                0  ...          0           0             0           0
# 20061                0  ...          0           0             0           0
# 40019                0  ...          0           0             0           1
# 83274                0  ...          1           0             0           0
# 43781                0  ...          0           0             0           0
# 289                  0  ...          0           0             0           0
#
#        brand_skoda  brand_toyota  brand_vauxhall  brand_vw  price_diff_pct  \
# 11984            0             0               0         1      851.316367
# 71819            0             0               0         0      693.546643
# 39711            0             0               0         0      659.223518
# 39978            0             0               0         0      659.205980
# 69135            0             0               0         0      461.828848
# 39540            0             0               0         0      416.822623
# 44539            0             0               1         0      410.986871
# 77582            0             0               0         0      337.871134
# 71617            0             0               0         0      337.533209
# 40171            0             0               0         0      322.851942
# 47201            0             0               1         0      293.833306
# 72349            0             0               0         0      286.168190
# 40172            0             0               0         0      285.449679
# 78800            0             0               0         0      281.541918
# 44553            0             0               1         0      279.077066
# 20061            0             0               0         1      259.140120
# 40019            0             0               0         0      258.696061
# 83274            0             0               0         0      252.627512
# 43781            0             0               1         0      248.514351
# 289              0             1               0         0      235.588452
#
#        price_diff_abs
# 11984      851.316367
# 71819      693.546643
# 39711      659.223518
# 39978      659.205980
# 69135      461.828848
# 39540      416.822623
# 44539      410.986871
# 77582      337.871134
# 71617      337.533209
# 40171      322.851942
# 47201      293.833306
# 72349      286.168190
# 40172      285.449679
# 78800      281.541918
# 44553      279.077066
# 20061      259.140120
# 40019      258.696061
# 83274      252.627512
# 43781      248.514351
# 289        235.588452
#
# [20 rows x 221 columns]

# %% [markdown]
# ### Most of these models are older. The top cases have a weird combination of low car mileage but older year model

# %%
feature_table = CarPrice_NN_bigger_2.linear_feature_importance(features,plot=True)

# %% [markdown]
# ### Let's tune learning rate

# %%
params = np.power(0.1,np.arange(0.5,7))

# %%
partial_model = partial(NnCarPrice.make_model,[2056,2014,512,512],input_size,METRICS,1e-4)

# %%
NnCarPrice.param_search(params,partial_model,train_dataset,dev_dataset,1)
# Out:
# 311/311 [==============================] - 1s 4ms/step - loss: nan - MAPE: nan - MAE: nan - val_loss: nan - val_MAPE: nan - val_MAE: nan
# 311/311 [==============================] - 1s 4ms/step - loss: 279210688.0000 - MAPE: 38.0418 - MAE: 5196.5649 - val_loss: 14580300.0000 - val_MAPE: 14.3062 - val_MAE: 2135.9133
# 311/311 [==============================] - 1s 4ms/step - loss: 26165066.0000 - MAPE: 18.6864 - MAE: 2859.3875 - val_loss: 11359669.0000 - val_MAPE: 12.4927 - val_MAE: 1971.1975
# 311/311 [==============================] - 1s 4ms/step - loss: 75860688.0000 - MAPE: 33.6144 - MAE: 5190.7563 - val_loss: 18587792.0000 - val_MAPE: 15.3666 - val_MAE: 2425.9827
# 311/311 [==============================] - 1s 4ms/step - loss: 284930336.0000 - MAPE: 77.9029 - MAE: 13384.5322 - val_loss: 111650376.0000 - val_MAPE: 54.3125 - val_MAE: 7295.1118
# 311/311 [==============================] - 1s 3ms/step - loss: 379676288.0000 - MAPE: 99.9643 - MAE: 16813.6016 - val_loss: 387950816.0000 - val_MAPE: 99.8924 - val_MAE: 16829.3359
# 311/311 [==============================] - 1s 4ms/step - loss: 379815616.0000 - MAPE: 99.9977 - MAE: 16817.8125 - val_loss: 388376320.0000 - val_MAPE: 99.9959 - val_MAE: 16842.1699

# %% [markdown]
# ### appears learning rate between 10-2 and 10-3 would work great

# %%
params_2 = [0.05,0.025,0.01,0.005,0.0025,0.001,0.0005]

# %%
NnCarPrice.param_search(params_2,partial_model,train_dataset,dev_dataset,1)
# Out:
# 311/311 [==============================] - 1s 4ms/step - loss: 48848252698624.0000 - MAPE: 14223.5342 - MAE: 1780518.2500 - val_loss: 9875449970688.0000 - val_MAPE: 20224.4355 - val_MAE: 2563465.0000
# 311/311 [==============================] - 1s 4ms/step - loss: 68253016.0000 - MAPE: 23.0886 - MAE: 3327.5544 - val_loss: 12666697.0000 - val_MAPE: 12.4969 - val_MAE: 2036.1216
# 311/311 [==============================] - 1s 4ms/step - loss: 18501076.0000 - MAPE: 16.7746 - MAE: 2569.8931 - val_loss: 11627215.0000 - val_MAPE: 17.0728 - val_MAE: 2323.8933
# 311/311 [==============================] - 1s 4ms/step - loss: 26101390.0000 - MAPE: 18.3230 - MAE: 2846.0432 - val_loss: 11407042.0000 - val_MAPE: 11.8832 - val_MAE: 1914.7935
# 311/311 [==============================] - 1s 4ms/step - loss: 28397666.0000 - MAPE: 19.1420 - MAE: 2964.1182 - val_loss: 13154283.0000 - val_MAPE: 14.4777 - val_MAE: 2243.0457
# 311/311 [==============================] - 1s 4ms/step - loss: 42098856.0000 - MAPE: 23.4481 - MAE: 3608.0188 - val_loss: 13843218.0000 - val_MAPE: 13.9842 - val_MAE: 2149.2214
# 311/311 [==============================] - 1s 4ms/step - loss: 59917300.0000 - MAPE: 28.7205 - MAE: 4430.6060 - val_loss: 16334608.0000 - val_MAPE: 14.6730 - val_MAE: 2272.3633

# %% [markdown]
# ### It appears lr of 0.001 works the best which we already use

# %% [markdown]
# ### The NN models have mostly car model type as top and bottom features
#
# ### With limited data, decision tree/RF still performs the best
#
# ### Let's check if the performance improves with categorical embedding
#
# ____
